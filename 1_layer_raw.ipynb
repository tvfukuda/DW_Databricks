# %% [markdown]
# # Get data of raw layer
#
# **Objective:** Data ingestion from a remote source to `raw` directory of DBFS.

# %% [markdown]
# ## Configuration
#
# Add your name to file:
# <a href="$./includes/configuration" target="_blank">
# includes/configuration</a>
#
# `username = "your_name"`

# %%
# %run ./includes/configuration
# Out:
# Out[3]: DataFrame[]

# %% [markdown]
# ## Clean up

# %%
dbutils.fs.rm(northwind_path, recurse=True)

for table_name in northwind_tables_trusted:
  spark.sql(
    f"""
    DROP TABLE IF EXISTS {table_name}
    """
  )

for table_name in northwind_tables_refined:
  spark.sql(
    f"""
    DROP TABLE IF EXISTS {table_name}
    """
  )

# %% [markdown]
# ## Get data
#
# Function `retrieve_data` is used to get data for ingestion.
# This function receives arguments:
# - `file_name: str`
# - `raw_path: str`

# %% [markdown]
# #### Import CSV files

# %%
dbutils.fs.mkdirs(raw_path)

for file_name in northwind_files:
  retrieve_data(file_name, raw_path)

# %% [markdown]
# ### Expected files
#
# List of expected files was defined in:
# <a href="$./includes/configuration" target="_blank">
# includes/configuration</a>

# %%
file_names = northwind_files

# %% [markdown]
# ### Files in `raw` folder

# %%
display(dbutils.fs.ls(raw_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/tfukuda/northwind_dw/raw/categories.csv</td><td>categories.csv</td><td>427</td><td>1654514509000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/customer_customer_demo.csv</td><td>customer_customer_demo.csv</td><td>29</td><td>1654514510000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/customer_demographics.csv</td><td>customer_demographics.csv</td><td>31</td><td>1654514511000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/customers.csv</td><td>customers.csv</td><td>11563</td><td>1654514512000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/employee_territories.csv</td><td>employee_territories.csv</td><td>417</td><td>1654514513000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/employees.csv</td><td>employees.csv</td><td>4070</td><td>1654514513000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/order_details.csv</td><td>order_details.csv</td><td>40625</td><td>1654514514000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/orders.csv</td><td>orders.csv</td><td>98531</td><td>1654514515000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/products.csv</td><td>products.csv</td><td>4339</td><td>1654514516000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/region.csv</td><td>region.csv</td><td>71</td><td>1654514516000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/shippers.csv</td><td>shippers.csv</td><td>205</td><td>1654514517000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/suppliers.csv</td><td>suppliers.csv</td><td>4012</td><td>1654514517000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/territories.csv</td><td>territories.csv</td><td>978</td><td>1654514518000</td></tr><tr><td>dbfs:/tfukuda/northwind_dw/raw/us_states.csv</td><td>us_states.csv</td><td>1139</td><td>1654514519000</td></tr></tbody></table></div>

# %% [markdown]
# Using `assert` function to verify ingested files
#
# **Note**: `print()` or `display()` is not used in production. It is just for test purpose.

# %%
# Validation of ingestion
for file_name in file_names:
  assert file_name in [item.name for item in dbutils.fs.ls(raw_path)], f"{file_name} not present in Raw Path"
print("Assertion passed - files ingested.")
# Out:
# Assertion passed - files ingested.
